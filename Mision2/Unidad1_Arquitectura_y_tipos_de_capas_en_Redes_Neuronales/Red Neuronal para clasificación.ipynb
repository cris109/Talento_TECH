# %% [markdown]
# * Importar bibliotecas

# %%
import keras
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

# %% [markdown]
# * Genaración de datos de clasificación sintéticos

# %%
X, y = make_classification(n_samples=100, n_features=5, n_classes=2)

# %% [markdown]
# * División de los datos

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# * Codificación one-hot de las etiquetas

# %%
y_train_categorical = keras.utils.to_categorical(y_train)
y_test_categorical = keras.utils.to_categorical(y_test)

# %% [markdown]
# * Creación del modelo

# %%
model = keras.models.Sequential()

# %% [markdown]
# * Añadir capas al modelo

# %%
# Añadir una capa oculta con 10 neuronas y activación ReLU
model.add(keras.layers.Dense(10,
                             input_shape = (X_train.shape[1],),
                             activation = 'relu'))

# Añadir una capa de salida con 2 neuronas (una para cada clase) y activación softmax
model.add(keras.layers.Dense(2, activation='softmax'))

# %% [markdown]
# * Compilación del modelo

# %%
model.compile(optimizer= 'adam',
             loss='categorical_crossentropy',
             metrics = ['accuracy'])

# %% [markdown]
# * Entrenamiento del modelo

# %%
model.fit(X_train, y_train_categorical, epochs=10,
          batch_size=32,
          validation_data=(X_test, y_test_categorical))
# Out:
# Epoch 1/10
# 3/3 [==============================] - 1s 136ms/step - loss: 0.4413 - accuracy: 0.8250 - val_loss: 0.4890 - val_accuracy: 0.8000
# Epoch 2/10
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4341 - accuracy: 0.8250 - val_loss: 0.4836 - val_accuracy: 0.8000
# Epoch 3/10
# 3/3 [==============================] - 0s 30ms/step - loss: 0.4283 - accuracy: 0.8250 - val_loss: 0.4783 - val_accuracy: 0.8000
# Epoch 4/10
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4225 - accuracy: 0.8250 - val_loss: 0.4736 - val_accuracy: 0.8000
# Epoch 5/10
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4169 - accuracy: 0.8250 - val_loss: 0.4695 - val_accuracy: 0.8000
# Epoch 6/10
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4124 - accuracy: 0.8250 - val_loss: 0.4649 - val_accuracy: 0.8000
# Epoch 7/10
# 3/3 [==============================] - 0s 29ms/step - loss: 0.4066 - accuracy: 0.8375 - val_loss: 0.4613 - val_accuracy: 0.8000
# Epoch 8/10
# 3/3 [==============================] - 0s 21ms/step - loss: 0.4034 - accuracy: 0.8375 - val_loss: 0.4576 - val_accuracy: 0.7500
# Epoch 9/10
# 3/3 [==============================] - 0s 20ms/step - loss: 0.3985 - accuracy: 0.8625 - val_loss: 0.4546 - val_accuracy: 0.7500
# Epoch 10/10
# 3/3 [==============================] - 0s 30ms/step - loss: 0.3957 - accuracy: 0.8625 - val_loss: 0.4517 - val_accuracy: 0.7500

# %% [markdown]
# * Evaluación del modelo

# %%
loss, accuracy = model.evaluate(X_test, y_test_categorical)
# Out:
# 1/1 [==============================] - 0s 28ms/step - loss: 0.7462 - accuracy: 0.6500

# %% [markdown]
# * Impresión de los resultados

# %%
print("Pérdida en el conjunto de prueba:", loss)
print("Precisión en el conjunto de prueba:", accuracy)
# Out:
# Pérdida en el conjunto de prueba: 0.7462136149406433
# Precisión en el conjunto de prueba: 0.6499999761581421
